# %% [markdown]
# # Experiment 3

# %% [markdown]
# ### Task 1: Write a Python program which accepts the user's first and last name and print them in reverse order with a space between them.

# %% [markdown]
# input():
#
# input() function reads a line from sys.stdin and returns it with the trailing newline stripped.
#
# To assign the user's name to a variable you can use following command :
#
# name = input('Input your name: ')

# %% [markdown]
# ### Sample Solution:

# %% [markdown]
# ### Python Code:

# %%
print("enter your first name")
name= input()
print("enter your last name")
surname =input()
print(surname + ' ' + name)
# Out:
# enter your first name
# entr your last name
# mahajan shriya

# %% [markdown]
# ### Explanation:

# %% [markdown]
# ### Task 2: Write a Python program to display the first and last colours from the following list. color_list = ["Red","Green","White" ,"Black"].

# %% [markdown]
# ### Python Code:

# %%
color_list=["red","green","white","black"]
print(color_list[0])
print(color_list[-1])
# Out:
# red
# black

# %% [markdown]
# Explanation:
