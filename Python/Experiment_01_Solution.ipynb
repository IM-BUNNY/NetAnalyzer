# %% [markdown]
# # Experiment 1

# %% [markdown]
# ### Task 1: Write a Python program to get the Python version you are using

# %% [markdown]
# ### Solution:

# %% [markdown]
# ### Python Code:

# %%
import sys
print("Python version")
print(sys.version)
print("Version info.")
print(sys.version_info)
# Out:
# Python version
# 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
# Version info.
# sys.version_info(major=3, minor=10, micro=12, releaselevel='final', serial=0)

# %% [markdown]
# ### Explanation:

# %% [markdown]
# ### Check the Python version on command line:

# %% [markdown]
# ### Python Code:

# %%
import sys
print("Python version")
print(sys.version)
print("Version info.")
print(sys.version_info)
# Out:
# Running cells with 'Python 3.11.7' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/ucrt64/bin/python3.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### Using platform module:

# %% [markdown]
# ### Python Code:

# %%
 import platform
 print(platform.python_version())
# Out:
# 3.10.12

# %% [markdown]
# Explanation:

# %% [markdown]
# ### Python Code:

# %%
import platform
print(platform.python_version_tuple())
# Out:
# ('3', '10', '12')

# %% [markdown]
# Explanation:

# %% [markdown]
# ### Task 2: Write a Python program which accepts the radius of a circle from the user and computes the area.

# %% [markdown]
# ### Sample Solution:-

# %% [markdown]
# ### Python Code:

# %%
from math import pi
r = float(input ("Input the radius of the circle : "))
print ("The area of the circle with radius " + str(r) + " is:" + str(pi * r**2))
# Out:
# Input the radius of the circle : 5
# The area of the circle with radius 5.0 is:78.53981633974483

# %% [markdown]
# Explanation:
