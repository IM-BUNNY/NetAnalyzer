# %% [markdown]
# # Experiment 2

# %% [markdown]
# ### Task 1: Write a Python program to display the current date and time.

# %% [markdown]
# Python datetime:
#
# The datetime module supplies classes for manipulating dates and times in both simple and complex ways. datetime.now(tz=None) returns the current local date and time. If optional argument tz is None or not specified, this is like today().
#
# date.strftime(format) returns a string representing the date, controlled by an explicit format string. Format codes referring to hours, minutes or seconds will see 0 values.

# %% [markdown]
# ### Python Code:

# %%
import datetime
now = datetime.datetime.now()
print("current date and time is")
print(now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# current date and time is
# 2024-07-23 16:11:28

# %% [markdown]
# ### Explanation:

# %% [markdown]
# ### Task 2 Write a Python Program to check whether a given number is even or odd using:
# (a) if-else and Modulus Operator
# (b) Bitwise Operator

# %%
num = int(input("enter a number"))
if(num % 2)==0:
 print(num,"is an even number")
else:
 print(num,"is a odd number")
# Out:
# 4 is an even number

# %%
# (b) Bitwise Operator
num = int(input("enter the numebr"))
if num & 1 == 0:
 print(num,"is an even number")
else: 
 print(num,"is an odd number")
# Out:
# 5 is an odd number

# %% [markdown]
# ### Task 3: Write a Python Program to Convert Centimeters to Feet and Inches

# %%
num = int(input("enter the number in cm"))
n = 1/2.5 * num
print(num,"in inches =",n)
n1 = 1/30 * num
print(num , "in feets =",n1)
# Out:
# 10 in inches = 4.0
# 10 in feets = 0.3333333333333333

# %% [markdown]
# 1 inch =2.5 cm
# 1 cm= 1/2.5 inch
# 1 cm= 1/30 feet
